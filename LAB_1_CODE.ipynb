# %% [markdown]
# <a href="https://colab.research.google.com/github/charlesdominictan/CPE-201-CPE2-B/blob/main/LAB_1_CODE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Polygons:
    def __init__(self, name: str, sides: int, area: float):
        self.name = name
        self.sides = sides
        self.area = area

    def set_name(self, name: str):
        self.name = name

    def set_sides(self, sides: int):
        self.sides = sides
        print(f"Sides set to: {self.sides}")

    def set_area(self, area: float):
        self.area = area

    def get_name(self) -> str:
        return self.name

    def get_sides(self) -> int:
        return self.sides

    def get_area(self) -> float:
        return self.area


# Test the class
polygon = Polygons("Triangle", 3, 15.5)

print(polygon.get_name())
print(polygon.get_sides())
print(polygon.get_area())

polygon.set_name("Square")
polygon.set_sides(4)
polygon.set_area(20.0)

print(polygon.get_name())
print(polygon.get_sides())
print(polygon.get_area())
# Out:
# Triangle
# 3
# 15.5
# Sides set to: 4
# Square
# 4
# 20.0
